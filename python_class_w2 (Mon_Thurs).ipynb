# %% [markdown]
# <a href="https://colab.research.google.com/github/HikmahAlBaity/Wisdom/blob/main/python_class_w2%20(Mon_Thurs).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# wednesday , 17/7/24

# %% [markdown]
# #**Numerical and categorical**
# # NumPy
# Create A Sample Dataset With Various Datatypes Using Numpy
#
#
#
# 1.   Types of data (numerical, categorical, and datetime)

# %% [markdown]
# Difference Between np.linspace and np.random function.
#
# 1.  numpy.linspace (np.linspace)
#
# Purpose: To generate evenly spaced numbers over a specified range.
#
# Usage: numpy.linspace(start, stop, num)
#
# Parameters:
#
# start: The starting value of the sequence.
# stop: The end value of the sequence.
# num: The number of samples to generate (including the start and stop values).
#
# 2.   numpy.random (np.random)
#
#
# Purpose: To generate random numbers.
# Usage: numpy.random provides several methods to generate random numbers, including:
# numpy.random.rand(d0, d1, ..., dn): Uniform distribution over [0, 1).
# numpy.random.randn(d0, d1, ..., dn): Standard normal distribution (mean 0, variance 1).
# numpy.random.randint(low, high=None, size=None, dtype='l'): Random integers from low (inclusive) to high (exclusive).
# numpy.random.normal(loc=0.0, scale=1.0, size=None): Normal (Gaussian) distribution. And many others.
#
# Summary
#
# numpy.linspace: Generates a specified number of evenly spaced values over a given range. Useful for deterministic sequences where the exact values and their spacing are important.
#
# numpy.random: Generates random numbers from various distributions. Useful for creating random samples, simulations, or any situation where randomness is required.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

#create numerical data

col1 = np.random.normal(250, 10, 500)
col2 = np.random.normal(100, 20, 500)
col3 = np.random.normal(750, 5, 500)

#create categorical data

categorical_data = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
col4 = np.random.choice(categorical_data, 500)
col5 = np.random.choice(categorical_data, 500) #use np.random.choice for categorical data

#create date data

start_date = datetime(2022, 1, 1)
end_date = datetime(2024, 1, 1)

delta = end_date - start_date
date_list = [start_date + timedelta(days= x) for x in range(delta.days)]

col6 = np.random.choice(date_list, 500)

#combine all the column/ features

data = np.column_stack((col1, col2, col3, col4, col5, col6)) # array in 2d


# rename the columns
df = pd.DataFrame(data, columns = ['Num1', 'Num2', 'Num3', 'Cat1', 'Cat2','Date'])
df.head()
# Out:
#          Num1        Num2        Num3 Cat1 Cat2       Date
# 0  250.380875  105.858652  755.086003    A    H 2023-06-07
# 1  260.773241   102.59589  740.868804    C    E 2022-01-19
# 2  246.622175   74.069872  755.867628    A    I 2023-07-03
# 3  253.338671   98.114823  747.038057    B    B 2023-06-02
# 4   247.90984  110.078292  742.283766    B    H 2023-04-20

# %% [markdown]
# col1 = np.random.normal(250, 10, 500)
#
# What It Means
# np.random.normal: This function creates random numbers.
#
# 250: The average value of the numbers (most will be around this number).
#
# 10: The "spread" or "variation" of the numbers (how much they can differ from the average).
#
# 500: How many numbers to create.

# %%
df.shape
# Out:
# (500, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Num1    500 non-null    object
#  1   Num2    500 non-null    object
#  2   Num3    500 non-null    object
#  3   Cat1    500 non-null    object
#  4   Cat2    500 non-null    object
#  5   Date    500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 23.6+ KB

# %%
df.describe() # only statistic of numbers
# Out:
#                                 Date
# count                            500
# mean   2022-12-26 10:24:57.600000256
# min              2022-01-02 00:00:00
# 25%              2022-06-29 12:00:00
# 50%              2023-01-03 12:00:00
# 75%              2023-06-13 00:00:00
# max              2023-12-31 00:00:00

# %%
df.describe(include = 'all') # unique is
# Out:
#               Num1        Num2        Num3 Cat1 Cat2  \
# count   500.000000  500.000000  500.000000  500  500
# unique  500.000000  500.000000  500.000000   10   10
# top     250.380875  105.858652  755.086003    I    J
# freq      1.000000    1.000000    1.000000   58   62
# mean           NaN         NaN         NaN  NaN  NaN
# min            NaN         NaN         NaN  NaN  NaN
# 25%            NaN         NaN         NaN  NaN  NaN
# 50%            NaN         NaN         NaN  NaN  NaN
# 75%            NaN         NaN         NaN  NaN  NaN
# max            NaN         NaN         NaN  NaN  NaN
#
#                                  Date
# count                             500
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2022-12-26 10:24:57.600000256
# min               2022-01-02 00:00:00
# 25%               2022-06-29 12:00:00
# 50%               2023-01-03 12:00:00
# ...

# %%
#You will notice that 'num1' num2' 'num3' is considered "object" not float ( refer to df.info () )
#Note: So it's normal for Python to labelled the datatype wrongly, so we have to fix it! - using astype

# to change data type
df['Num1'] = df['Num1'].astype ('float') # change one at a time
df[['Num2', 'Num3']] = df[['Num2', 'Num3']].astype ('float') # change multiple at a time

df.dtypes
# Out:
# Num1           float64
# Num2           float64
# Num3           float64
# Cat1            object
# Cat2            object
# Date    datetime64[ns]
# dtype: object

# %%
df.describe ()
# Out:
#              Num1        Num2        Num3                           Date
# count  500.000000  500.000000  500.000000                            500
# mean   249.157632   98.701081  750.317712  2022-12-26 10:24:57.600000256
# min    207.868679   45.791815  732.097607            2022-01-02 00:00:00
# 25%    242.782035   85.441370  746.986213            2022-06-29 12:00:00
# 50%    248.994594   99.526731  750.443751            2023-01-03 12:00:00
# 75%    256.135375  111.325010  753.939752            2023-06-13 00:00:00
# max    278.661192  184.834506  763.341965            2023-12-31 00:00:00
# std      9.385442   19.791403    5.034382                            NaN

# %%
df. describe(include = 'all')
# Out:
#               Num1        Num2        Num3 Cat1 Cat2  \
# count   500.000000  500.000000  500.000000  500  500
# unique         NaN         NaN         NaN   10   10
# top            NaN         NaN         NaN    I    J
# freq           NaN         NaN         NaN   58   62
# mean    249.157632   98.701081  750.317712  NaN  NaN
# min     207.868679   45.791815  732.097607  NaN  NaN
# 25%     242.782035   85.441370  746.986213  NaN  NaN
# 50%     248.994594   99.526731  750.443751  NaN  NaN
# 75%     256.135375  111.325010  753.939752  NaN  NaN
# max     278.661192  184.834506  763.341965  NaN  NaN
# std       9.385442   19.791403    5.034382  NaN  NaN
#
#                                  Date
# count                             500
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2022-12-26 10:24:57.600000256
# min               2022-01-02 00:00:00
# 25%               2022-06-29 12:00:00
# ...

# %% [markdown]
# Assignment

# %%
#self_test

#numerical data (Test score)

col1 = np.random.normal(70, 10, 60)
col2 = np.random.normal(80, 10, 60)
col3 = np.random.normal(50, 10, 60)

#categorical data

categorical_data = ['A', 'B', 'C']
col4 = np.random.choice(categorical_data, 60)
col5 = np.random.choice(categorical_data, 60)

#create date data

start_date = datetime(2022, 1, 1)
end_date = datetime(2024, 1, 1)

delta = end_date - start_date
date_list = [start_date + timedelta(days= x) for x in range(delta.days)]

col6 = np.random.choice(date_list, 60)

#combine all the column/ features

data = np.column_stack((col1, col2, col3, col4, col5, col6)) # array in 2d

df_1 = pd.DataFrame(data, columns = ['Score1', 'Score2', 'Score3', 'Cat1', 'Cat2','Date'])
df_1.head(61)
# Out:
#        Score1      Score2     Score3 Cat1 Cat2       Date
# 0   76.901951   75.072832  42.903241    B    C 2022-12-27
# 1   87.149975   78.889647  44.041617    C    B 2022-01-07
# 2   60.096334    70.78149  41.119856    C    C 2023-03-15
# 3   84.736547   88.880351  34.433738    A    B 2023-06-20
# 4   82.729045   65.740079  54.871267    C    C 2023-02-08
# 5   76.292233    67.81983  41.570241    A    B 2022-01-12
# 6   90.354309   69.163879   57.01835    B    C 2022-10-18
# 7   72.873071   95.382933  43.672229    A    C 2023-02-14
# 8   69.310866   83.911051  58.114894    A    C 2023-12-19
# 9   62.602248   73.559493  44.564457    B    C 2022-06-27
# 10  93.280137   91.876595  52.075287    C    B 2022-03-31
# 11  66.930322   79.461083  64.893953    C    A 2023-02-04
# 12   72.01372     83.6911  42.235068    A    C 2022-05-01
# 13   60.16688   82.100445  64.642203    B    B 2023-04-12
# 14  64.649892    73.89413  61.640506    C    A 2023-10-23
# ...

# %%
df_1.shape
# Out:
# (60, 6)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Score1  60 non-null     object
#  1   Score2  60 non-null     object
#  2   Score3  60 non-null     object
#  3   Cat1    60 non-null     object
#  4   Cat2    60 non-null     object
#  5   Date    60 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 2.9+ KB

# %%
df_1.describe()
# Out:
#                       Date
# count                   60
# mean   2022-11-30 22:00:00
# min    2022-01-07 00:00:00
# 25%    2022-05-03 18:00:00
# 50%    2022-10-16 12:00:00
# 75%    2023-04-20 06:00:00
# max    2023-12-25 00:00:00

# %%
df_1.describe(include = 'all')
# Out:
#            Score1     Score2     Score3 Cat1 Cat2                 Date
# count   60.000000  60.000000  60.000000   60   60                   60
# unique  60.000000  60.000000  60.000000    3    3                  NaN
# top     76.901951  75.072832  42.903241    C    C                  NaN
# freq     1.000000   1.000000   1.000000   24   24                  NaN
# mean          NaN        NaN        NaN  NaN  NaN  2022-11-30 22:00:00
# min           NaN        NaN        NaN  NaN  NaN  2022-01-07 00:00:00
# 25%           NaN        NaN        NaN  NaN  NaN  2022-05-03 18:00:00
# 50%           NaN        NaN        NaN  NaN  NaN  2022-10-16 12:00:00
# 75%           NaN        NaN        NaN  NaN  NaN  2023-04-20 06:00:00
# max           NaN        NaN        NaN  NaN  NaN  2023-12-25 00:00:00

# %% [markdown]
# df.describe(include='all') is a function in pandas that gives you a summary of your DataFrame. It provides key statistics for each column, including both numbers and text. Here's a breakdown:
#
#
# *   For numerical columns, it shows: count, mean, standard deviation,min, 25th percentile, median (50th percentile), 75th percentile, and max.
#
# *   For categorical (text) columns, it shows: count, number of unique values, the most frequent value (top), and how often the most frequent value appears (freq).
#
# Using include='all' ensures you get this information for every column, no matter the type.

# %%
 #to change data type
df_1['Score1'] = df_1['Score1'].astype ('float')
df_1[['Score2', 'Score3']] = df_1[['Score2', 'Score3']].astype ('float')

df_1.dtypes
# Out:
# Score1           float64
# Score2           float64
# Score3           float64
# Cat1              object
# Cat2              object
# Date      datetime64[ns]
# dtype: object

# %%
df_1.describe(include = 'all')
# Out:
#            Score1      Score2     Score3 Cat1 Cat2                 Date
# count   60.000000   60.000000  60.000000   60   60                   60
# unique        NaN         NaN        NaN    3    3                  NaN
# top           NaN         NaN        NaN    C    C                  NaN
# freq          NaN         NaN        NaN   24   24                  NaN
# mean    71.548417   81.540376  49.114686  NaN  NaN  2022-11-30 22:00:00
# min     46.052824   46.745763  23.016220  NaN  NaN  2022-01-07 00:00:00
# 25%     63.484065   73.481011  43.614548  NaN  NaN  2022-05-03 18:00:00
# 50%     71.042782   82.015621  48.762051  NaN  NaN  2022-10-16 12:00:00
# 75%     79.107979   90.212636  56.789452  NaN  NaN  2023-04-20 06:00:00
# max     96.681101  102.419617  65.964897  NaN  NaN  2023-12-25 00:00:00
# std     11.527678   11.527669   9.275731  NaN  NaN                  NaN

# %% [markdown]
# #Matplotlib: plotting library for Python (Visualisation of data)

# %%
#Matplotlib: plotting library for Python (Visualisation of data)
# Graph plot

from matplotlib import pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis

plt.plot(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y)

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis

plt.plot(x1, y1)
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y)

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y)

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y)

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B'])

plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, '--') # to change common 'line' to dash using '--'


x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, '--')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B'])

plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, color = 'g', linestyle = '--', marker = 'o') # to change common 'line' to dash using '--'


x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, color = 'y', linestyle = '-', marker = 'o')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B'])

plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, color = 'g', linestyle = '--', marker = 'o') # to change common 'line' to dash using '--'


x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, color = 'y', linestyle = '-', marker = 'o')

x2 = [0, 1, 2, 3, 4, 5, 6, 7]# x-axis
y2 = [2, 6, 7, 8, 10, 11, 13, 14]# x-axis
plt.plot(x2, y2, color = 'b', linestyle = '-', marker = 'o')

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B', 'Company C'])

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, color = 'g', linestyle = '-', marker = 'o', linewidth = 1) # to change common 'line' to dash using '--'


x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, color = 'y', linestyle = '-', marker = 'o', linewidth = 4)

x2 = [0, 1, 2, 3, 4, 5, 6, 7]# x-axis
y2 = [2, 6, 7, 8, 10, 11, 13, 14]# x-axis
plt.plot(x2, y2, color = 'b', linestyle = '-', marker = 'o', linewidth = 5)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B', 'Company C'])

# %%
#Checking All Available Style in Matplot Library
print (plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#Changing the visual style from the list of library:
# plt.style.use('name of style')
# Reset visual: plt.style.use('default')

# %%
plt.style.use('default')

x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, color = 'g', linestyle = '-', marker = 'o', linewidth = 1) # to change common 'line' to dash using '--'


x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, color = 'y', linestyle = '-', marker = 'o', linewidth = 4)

x2 = [0, 1, 2, 3, 4, 5, 6, 7]# x-axis
y2 = [2, 6, 7, 8, 10, 11, 13, 14]# x-axis
plt.plot(x2, y2, color = 'b', linestyle = '-', marker = 'o', linewidth = 5)

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B', 'Company C'])

plt.grid(True) # have grid at the back of the graph

plt.show()

# %%
#NOTE!!!

#If plt.grid() doesn't work
#Then add 'True' to the parameter
#plt.grid(True)

# %%
# Bar Chart
from matplotlib import pyplot as plt


x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.bar(x, y, color = 'g')

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.bar(x1, y1, color = 'y')

x2 = [0, 1, 2, 3, 4, 5, 6, 7]# x-axis
y2 = [2, 6, 7, 8, 10, 11, 13, 14]# x-axis
plt.bar(x2, y2, color = 'b')

# Add labels title, grid, and adjusting the size of the visual

plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B', 'Company C'])

plt.figure(figsize=(8, 6)) #Adjusting size of visual


plt.show()

# %% [markdown]
# plt.figure(...) creates a new figure.
# figsize=(8, 6) sets the width of the figure to 8 inches and the height to 6 inches.
#
# This is useful when you want to control the size of your plots for better readability or to fit them into specific formats (like presentations or reports).

# %%
# combining plot with bar chart

x = [1, 2, 3, 4, 5, 6, 7, 8]# x-axis
y = [4, 7, 9, 10, 13, 15, 17, 19]  # y-axis
plt.plot(x, y, color = 'g', linestyle = '-', marker = 'o', linewidth = 1) # to change common 'line' to dash using '--'
plt.bar(x, y, color = 'g')

x1 = [2, 3, 5, 6, 7, 8, 10]# x-axis
y1 = [3, 5, 8, 11, 14, 16, 18]# x-axis
plt.plot(x1, y1, color = 'y', linestyle = '-', marker = 'o', linewidth = 1)
plt.bar(x1, y1, color = 'y')

x2 = [0, 1, 2, 3, 4, 5, 6, 7]# x-axis
y2 = [2, 6, 7, 8, 10, 11, 13, 14]# x-axis
plt.plot(x2, y2, color = 'b', linestyle = '-', marker = 'o', linewidth = 1)
plt.bar(x2, y2, color = 'b')


plt.xlabel('Number of Years')
plt.ylabel('Salary in RM')

plt.title('Salary in Kuala Lumpur')

plt.legend(['Company A', 'Company B', 'Company C'])

plt.figure(figsize=(8, 6)) #Adjusting size of visual

plt.show()

# %%
plt.figure(figsize=(8, 6))
bars = plt.bar(categories, values, color='skyblue')

# Add the value of each bar on top of the bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval}', ha='center', va='bottom', fontsize=12)

# %%
#generate random data
data = np.random.random ((5,5))


plt.imshow(data)

plt.show()

# %%
plt.style.use('fivethirtyeight')

data = np.random.random ((5,5))


plt.imshow(data)
plt.colorbar (label = 'color Intensity')

plt.show()

# %%
data = np.random.random ((5,5))


plt.imshow(data)

plt.show()

# %%
import geopandas as gpd

# Load a world map using GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a geographic heatmap
world.plot(column='gdp_md_est', cmap='OrRd', legend=True)
plt.title('Geographic Heatmap of GDP')
plt.show()
# Out:
# <ipython-input-77-398cbca0dfd0>:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# %whos
# Out:
# Variable           Type            Data/Info
# --------------------------------------------
# categorical_data   list            n=3
# col1               ndarray         60: 60 elems, type `float64`, 480 bytes
# col2               ndarray         60: 60 elems, type `float64`, 480 bytes
# col3               ndarray         60: 60 elems, type `float64`, 480 bytes
# col4               ndarray         60: 60 elems, type `<U1`, 240 bytes
# col5               ndarray         60: 60 elems, type `<U1`, 240 bytes
# col6               ndarray         60: 60 elems, type `object`, 480 bytes
# data               ndarray         5x5: 25 elems, type `float64`, 200 bytes
# date_list          list            n=730
# datetime           type            <class 'datetime.datetime'>
# delta              timedelta       730 days, 0:00:00
# df                 DataFrame                  Num1        Nu<...>n\n[500 rows x 6 columns]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate random data
Z1 = [1, 2, 3, 4, 5, 6, 7, 8]
# Optional: Normalize the data if you want them to sum to a specific total (like 1)
Z = Z / Z.sum()

# Step 2: Create a pie chart
plt.pie(Z, labels=['A', 'B', 'C', 'D'], autopct='%1.1f%%')

# Step 3: Display the plot
plt.title("Randomly Generated Pie Chart")
plt.show()

# %%
# pie chart

Z = np.random.uniform(0, 1, 4)

# Optional: Normalize the data if you want them to sum to a specific total (like 1)
Z = Z / Z.sum()

# Step 2: Create a pie chart
plt.pie(Z, labels=['A', 'B', 'C', 'D'], autopct='%1.1f%%')

# Step 3: Display the plot
plt.title("Randomly Generated Pie Chart")
plt.show()

# %%
P = np.random.uniform(50, 5, 4)

# Optional: Normalize the data if you want them to sum to a specific total (like 1)
P = P / P.sum()

# Step 2: Create a pie chart
fig, ax = plt.subplots()
ax.pie(P, labels=['A', 'B', 'C', 'D'], autopct='%1.1f%%')

# Step 3: Display the plot
plt.title(" Pass the test Pie Chart")
plt.show()

# %%
P = np.random.uniform(50, 5, 4)
P = P / P.sum()
explode = [0, 0.1, 0, 0]  # Only the second slice will be exploded

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(P, explode=explode, labels=['A', 'B', 'C', 'D'], autopct='%1.1f%%', shadow=True)

# Display the plot
plt.title("Pie Chart with Exploded Slice")
plt.show()

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
import pandas as pd

df = pd.read_csv('NFLX.csv')


plt.figure(figsize=(15, 6))

plt.style.use('default')



x = df.iloc[:50, 2]
y = df.iloc[:50, 3]
plt.bar(x, y, color = 'g') # to change common 'line' to dash using '--'



plt.xlabel('High')
plt.ylabel('Low')

plt.title('NFLX')

plt.legend(['Netflix'])

plt.grid(True) # have grid at the back of the graph

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]



# Create a bar chart
plt.bar(categories, values)

# Add labels and title
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Simple Bar Chart')

# Show the plot
plt.show()

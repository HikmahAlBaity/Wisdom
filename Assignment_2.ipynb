# %% [markdown]
# <a href="https://colab.research.google.com/github/HikmahAlBaity/Wisdom/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create your own dataset, concatenante in terms of rows once, and in terms of colomns once again.

biofilm1 = {
    'Media': ['YPD', 'RPMI-1640', 'YPD', 'RPMI-1640', 'RPMI-1640', 'RPMI-1640', 'YPD', 'RPMI-1640' ],
    'Tx': ['AuAg', 'Au', 'Ag', 'Ag', 'AuAg', 'Au', 'Ag', 'Ag']}


df_biofilm1 = pd.DataFrame(biofilm1)
df_biofilm1.head(10)
# Out:
#        Media    Tx
# 0        YPD  AuAg
# 1  RPMI-1640    Au
# 2        YPD    Ag
# 3  RPMI-1640    Ag
# 4  RPMI-1640  AuAg
# 5  RPMI-1640    Au
# 6        YPD    Ag
# 7  RPMI-1640    Ag

# %%
df_biofilm1.shape
# Out:
# (8, 2)

# %%
import pandas as pd

# %%
biofilm2 = {
    'Media': ['YPD', 'RPMI-1640', 'YPD', 'RPMI-1640','YPD' , 'RPMI-1640', 'RPMI-1640', 'RPMI-1640' ],
    'Tx': ['Au', 'Au', 'Ag', 'Ag', 'AuAg', 'Au', 'Ag', 'Ag']}

df_biofilm2 = pd.DataFrame(biofilm2)
df_biofilm2.head(10)
# Out:
#        Media    Tx
# 0        YPD    Au
# 1  RPMI-1640    Au
# 2        YPD    Ag
# 3  RPMI-1640    Ag
# 4        YPD  AuAg
# 5  RPMI-1640    Au
# 6  RPMI-1640    Ag
# 7  RPMI-1640    Ag

# %%
df_biofilm2.shape
# Out:
# (8, 2)

# %%
# concatenante in terms of row

df_biofilm1_biofilm2 =[df_biofilm1, df_biofilm2]
df_b1_b2 = pd.concat(df_biofilm1_biofilm2)
df_b1_b2.head(20)
# Out:
#        Media    Tx
# 0        YPD  AuAg
# 1  RPMI-1640    Au
# 2        YPD    Ag
# 3  RPMI-1640    Ag
# 4  RPMI-1640  AuAg
# 5  RPMI-1640    Au
# 6        YPD    Ag
# 7  RPMI-1640    Ag
# 0        YPD    Au
# 1  RPMI-1640    Au
# 2        YPD    Ag
# 3  RPMI-1640    Ag
# 4        YPD  AuAg
# 5  RPMI-1640    Au
# 6  RPMI-1640    Ag
# 7  RPMI-1640    Ag

# %%
df_b1_b2.shape
# Out:
# (16, 2)

# %%
#reset index (row)
df_b1_b2 = df_b1_b2.reset_index(drop = True)
df_b1_b2.head(20)
# Out:
#         Media    Tx
# 0         YPD  AuAg
# 1   RPMI-1640    Au
# 2         YPD    Ag
# 3   RPMI-1640    Ag
# 4   RPMI-1640  AuAg
# 5   RPMI-1640    Au
# 6         YPD    Ag
# 7   RPMI-1640    Ag
# 8         YPD    Au
# 9   RPMI-1640    Au
# 10        YPD    Ag
# 11  RPMI-1640    Ag
# 12        YPD  AuAg
# 13  RPMI-1640    Au
# 14  RPMI-1640    Ag
# 15  RPMI-1640    Ag

# %%
df_b1_b2
# Out:
#         Media    Tx
# 0         YPD  AuAg
# 1   RPMI-1640    Au
# 2         YPD    Ag
# 3   RPMI-1640    Ag
# 4   RPMI-1640  AuAg
# 5   RPMI-1640    Au
# 6         YPD    Ag
# 7   RPMI-1640    Ag
# 8         YPD    Au
# 9   RPMI-1640    Au
# 10        YPD    Ag
# 11  RPMI-1640    Ag
# 12        YPD  AuAg
# 13  RPMI-1640    Au
# 14  RPMI-1640    Ag
# 15  RPMI-1640    Ag

# %%
Appearance = {
     'Colour': [ 'Blue', 'Green', 'Red', 'Blue', 'Blue', 'Green', 'Red', 'Blue', 'Blue', 'Yellow', 'Red', 'Yellow', 'Blue','Blue', 'Green', 'Yellow'],
     'cloudy': ['Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N']
}

df_Appearance = pd.DataFrame(Appearance)
df_Appearance.head(20)
# Out:
#     Colour cloudy
# 0     Blue      Y
# 1    Green      N
# 2      Red      N
# 3     Blue      N
# 4     Blue      Y
# 5    Green      N
# 6      Red      Y
# 7     Blue      N
# 8     Blue      Y
# 9   Yellow      N
# 10     Red      N
# 11  Yellow      N
# 12    Blue      Y
# 13    Blue      N
# 14   Green      Y
# 15  Yellow      N

# %%
#concatenante in terms colomns once again. (adding colomn)

df_all = [df_b1_b2, df_Appearance]
df_all_1 = pd.concat(df_all, axis=1)
df_all_1.head(20)
# Out:
#         Media    Tx  Colour cloudy
# 0         YPD  AuAg    Blue      Y
# 1   RPMI-1640    Au   Green      N
# 2         YPD    Ag     Red      N
# 3   RPMI-1640    Ag    Blue      N
# 4   RPMI-1640  AuAg    Blue      Y
# 5   RPMI-1640    Au   Green      N
# 6         YPD    Ag     Red      Y
# 7   RPMI-1640    Ag    Blue      N
# 8         YPD    Au    Blue      Y
# 9   RPMI-1640    Au  Yellow      N
# 10        YPD    Ag     Red      N
# 11  RPMI-1640    Ag  Yellow      N
# 12        YPD  AuAg    Blue      Y
# 13  RPMI-1640    Au    Blue      N
# 14  RPMI-1640    Ag   Green      Y
# 15  RPMI-1640    Ag  Yellow      N

# %%
# call cells #loc, iloc -to recall specific data in specific cells
#df.iloc[[row_index], [column_index]]
df_all_1.iloc[[2],[3]]
# Out:
#   cloudy
# 2      N

# %%
df_all_1.index # start rows from certain value
# Out:
# RangeIndex(start=0, stop=16, step=1)

# %%
df_all_1.columns # string in pandas called as object
# 2 files received ('.csv' & name of column)
# Out:
# Index(['Media', 'Tx', 'Colour', 'cloudy'], dtype='object')
